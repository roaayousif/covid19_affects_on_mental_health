# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mental_health_survey = pd.read_csv('../data/Indicators_of_Anxiety_or_Depression_Based_on_Reported_Frequency_of_Symptoms_During_Last_7_Days (4).csv')

# %%
#filter for data from april 2020 to april 2023
mental_health_survey = mental_health_survey.loc[mental_health_survey['Time Period'] <= 57]
mental_health_survey
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 13198  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13199  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13200  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13201  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13202  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#                State       Subgroup Phase  Time Period     Time Period Label  \
# 0      United States  United States     1            1  Apr 23 - May 5, 2020
# 1      United States  18 - 29 years     1            1  Apr 23 - May 5, 2020
# 2      United States  30 - 39 years     1            1  Apr 23 - May 5, 2020
# 3      United States  40 - 49 years     1            1  Apr 23 - May 5, 2020
# 4      United States  50 - 59 years     1            1  Apr 23 - May 5, 2020
# ...              ...            ...   ...          ...                   ...
# 13198       Virginia       Virginia   3.8           57  Apr 26 - May 8, 2023
# 13199     Washington     Washington   3.8           57  Apr 26 - May 8, 2023
# 13200  West Virginia  West Virginia   3.8           57  Apr 26 - May 8, 2023
# 13201      Wisconsin      Wisconsin   3.8           57  Apr 26 - May 8, 2023
# 13202        Wyoming        Wyoming   3.8           57  Apr 26 - May 8, 2023
#
#       Time Period Start Date Time Period End Date  Value  Low CI  High CI  \
# 0                 04/23/2020           05/05/2020   23.5    22.7     24.3
# 1                 04/23/2020           05/05/2020   32.7    30.2     35.2
# 2                 04/23/2020           05/05/2020   25.7    24.1     27.3
# 3                 04/23/2020           05/05/2020   24.8    23.3     26.2
# 4                 04/23/2020           05/05/2020   23.2    21.5     25.0
# ...                      ...                  ...    ...     ...      ...
# 13198             04/26/2023           05/08/2023   29.7    26.0     33.7
# 13199             04/26/2023           05/08/2023   31.2    28.2     34.3
# 13200             04/26/2023           05/08/2023   33.2    26.3     40.8
# 13201             04/26/2023           05/08/2023   27.5    23.9     31.3
# 13202             04/26/2023           05/08/2023   34.1    28.6     40.1
#
#       Confidence Interval Quartile Range
# 0             22.7 - 24.3            NaN
# 1             30.2 - 35.2            NaN
# 2             24.1 - 27.3            NaN
# 3             23.3 - 26.2            NaN
# 4             21.5 - 25.0            NaN
# ...                   ...            ...
# 13198         26.0 - 33.7      23.6-29.7
# 13199         28.2 - 34.3      29.8-31.5
# 13200         26.3 - 40.8      31.6-34.5
# 13201         23.9 - 31.3      23.6-29.7
# 13202         28.6 - 40.1      31.6-34.5
#
# [13203 rows x 14 columns]

# %%
mental_health_survey.describe()
# Out:
#         Time Period         Value        Low CI       High CI
# count  13203.000000  12582.000000  12582.000000  12582.000000
# mean      28.406953     29.760436     26.118050     33.649173
# std       17.202252      8.188520      7.970988      8.608858
# min        1.000000      6.400000      4.500000      7.900000
# 25%       13.000000     24.200000     20.700000     27.900000
# 50%       29.000000     29.100000     25.400000     33.100000
# 75%       43.000000     34.400000     30.600000     38.500000
# max       57.000000     82.000000     73.600000     88.800000

# %%
mental_health_survey.columns
# Out:
# Index(['Indicator', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period',
#        'Time Period Label', 'Time Period Start Date', 'Time Period End Date',
#        'Value', 'Low CI', 'High CI', 'Confidence Interval', 'Quartile Range'],
#       dtype='object')

# %%
mental_health_survey['Group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State',
#        'By Disability status', 'By Gender identity',
#        'By Sexual orientation'], dtype=object)

# %%
mental_health_survey['Indicator'].unique()
# Out:
# array(['Symptoms of Depressive Disorder', 'Symptoms of Anxiety Disorder',
#        'Symptoms of Anxiety Disorder or Depressive Disorder'],
#       dtype=object)

# %%
mental_health_survey['Group'].unique()
# Out:
# array(['National Estimate', 'By Age', 'By Sex',
#        'By Race/Hispanic ethnicity', 'By Education', 'By State',
#        'By Disability status', 'By Gender identity',
#        'By Sexual orientation'], dtype=object)

# %%
# dropped columns not needed
mental_health_survey = mental_health_survey[['Indicator', 'Group', 'State', 'Subgroup', 'Phase', 'Time Period',
       'Time Period Label', 'Time Period Start Date', 'Time Period End Date',
       'Value']]

# %%
mental_health_survey.dtypes
# Out:
# Indicator                  object
# Group                      object
# State                      object
# Subgroup                   object
# Phase                      object
# Time Period                 int64
# Time Period Label          object
# Time Period Start Date     object
# Time Period End Date       object
# Value                     float64
# dtype: object

# %%
# changed 'Time Period Start Date' column to date time data type from oject 
mental_health_survey['Time Period Start Date'] = pd.to_datetime(mental_health_survey['Time Period Start Date'])
# Out:
# C:\Users\Roaa\AppData\Local\Temp\ipykernel_15628\4081912926.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mental_health_survey['Time Period Start Date'] = pd.to_datetime(mental_health_survey['Time Period Start Date'])

# %%
#changed 'Time Period End Date' column to date time data type from oject 
mental_health_survey['Time Period End Date'] = pd.to_datetime(mental_health_survey['Time Period End Date'])
# Out:
# C:\Users\Roaa\AppData\Local\Temp\ipykernel_15628\3612650403.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mental_health_survey['Time Period End Date'] = pd.to_datetime(mental_health_survey['Time Period End Date'])

# %%
# replacing for consistency. Confirmed these fall under phase 3.0
phase_mapping = {
    '3 (Oct 28 - Dec 21)': '3',
    '3 (Jan 6 - Mar 29)': '3'}

# %%
mental_health_survey['Phase'] = mental_health_survey['Phase'].replace(phase_mapping)
# Out:
# C:\Users\Roaa\AppData\Local\Temp\ipykernel_15628\3920451747.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mental_health_survey['Phase'] = mental_health_survey['Phase'].replace(phase_mapping)

# %%
#changing the data type of the phase colun to a float 
mental_health_survey['Phase'] = mental_health_survey['Phase'].astype(float)
# Out:
# C:\Users\Roaa\AppData\Local\Temp\ipykernel_15628\1625970619.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mental_health_survey['Phase'] = mental_health_survey['Phase'].astype(float)

# %%
mental_health_survey.dtypes
# Out:
# Indicator                         object
# Group                             object
# State                             object
# Subgroup                          object
# Phase                            float64
# Time Period                        int64
# Time Period Label                 object
# Time Period Start Date    datetime64[ns]
# Time Period End Date      datetime64[ns]
# Value                            float64
# dtype: object

# %%
#looking for missing values 
mental_health_survey.isna().sum()
# Out:
# Indicator                   0
# Group                       0
# State                       0
# Subgroup                    0
# Phase                       0
# Time Period                 0
# Time Period Label           0
# Time Period Start Date      0
# Time Period End Date        0
# Value                     621
# dtype: int64

# %%
#investigated nans and found that survey was not sent out during those dates ( dates in between phases)
mental_health_survey[mental_health_survey['Value'].isna()]
# Out:
#                                                Indicator  \
# 2520                     Symptoms of Depressive Disorder
# 2521                     Symptoms of Depressive Disorder
# 2522                     Symptoms of Depressive Disorder
# 2523                     Symptoms of Depressive Disorder
# 2524                     Symptoms of Depressive Disorder
# ...                                                  ...
# 11950  Symptoms of Anxiety Disorder or Depressive Dis...
# 11951  Symptoms of Anxiety Disorder or Depressive Dis...
# 11952  Symptoms of Anxiety Disorder or Depressive Dis...
# 11953  Symptoms of Anxiety Disorder or Depressive Dis...
# 11954  Symptoms of Anxiety Disorder or Depressive Dis...
#
#                       Group          State                         Subgroup  \
# 2520      National Estimate  United States                    United States
# 2521                 By Age  United States                    18 - 29 years
# 2522                 By Age  United States                    30 - 39 years
# 2523                 By Age  United States                    40 - 49 years
# 2524                 By Age  United States                    50 - 59 years
# ...                     ...            ...                              ...
# 11950          By Education  United States       High school diploma or GED
# 11951          By Education  United States  Some college/Associate's degree
# 11952          By Education  United States      Bachelor's degree or higher
# 11953  By Disability status  United States                  With disability
# 11954  By Disability status  United States               Without disability
#
#        Phase  Time Period       Time Period Label Time Period Start Date  \
# 2520    -1.0            1  July 22 - Aug 18, 2020             2020-07-22
# 2521    -1.0            1  July 22 - Aug 18, 2020             2020-07-22
# 2522    -1.0            1  July 22 - Aug 18, 2020             2020-07-22
# 2523    -1.0            1  July 22 - Aug 18, 2020             2020-07-22
# 2524    -1.0            1  July 22 - Aug 18, 2020             2020-07-22
# ...      ...          ...                     ...                    ...
# 11950   -1.0            1    Nov 30 - Dec 8, 2022             2022-11-30
# 11951   -1.0            1    Nov 30 - Dec 8, 2022             2022-11-30
# 11952   -1.0            1    Nov 30 - Dec 8, 2022             2022-11-30
# 11953   -1.0            1    Nov 30 - Dec 8, 2022             2022-11-30
# 11954   -1.0            1    Nov 30 - Dec 8, 2022             2022-11-30
#
#       Time Period End Date  Value
# 2520            2020-08-18    NaN
# 2521            2020-08-18    NaN
# 2522            2020-08-18    NaN
# 2523            2020-08-18    NaN
# 2524            2020-08-18    NaN
# ...                    ...    ...
# 11950           2022-12-08    NaN
# 11951           2022-12-08    NaN
# 11952           2022-12-08    NaN
# 11953           2022-12-08    NaN
# 11954           2022-12-08    NaN
#
# [621 rows x 10 columns]

# %%
#dropping nans 
mental_health_survey= mental_health_survey.dropna() 
mental_health_survey
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 1                        Symptoms of Depressive Disorder             By Age
# 2                        Symptoms of Depressive Disorder             By Age
# 3                        Symptoms of Depressive Disorder             By Age
# 4                        Symptoms of Depressive Disorder             By Age
# ...                                                  ...                ...
# 13198  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13199  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13200  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13201  Symptoms of Anxiety Disorder or Depressive Dis...           By State
# 13202  Symptoms of Anxiety Disorder or Depressive Dis...           By State
#
#                State       Subgroup  Phase  Time Period     Time Period Label  \
# 0      United States  United States    1.0            1  Apr 23 - May 5, 2020
# 1      United States  18 - 29 years    1.0            1  Apr 23 - May 5, 2020
# 2      United States  30 - 39 years    1.0            1  Apr 23 - May 5, 2020
# 3      United States  40 - 49 years    1.0            1  Apr 23 - May 5, 2020
# 4      United States  50 - 59 years    1.0            1  Apr 23 - May 5, 2020
# ...              ...            ...    ...          ...                   ...
# 13198       Virginia       Virginia    3.8           57  Apr 26 - May 8, 2023
# 13199     Washington     Washington    3.8           57  Apr 26 - May 8, 2023
# 13200  West Virginia  West Virginia    3.8           57  Apr 26 - May 8, 2023
# 13201      Wisconsin      Wisconsin    3.8           57  Apr 26 - May 8, 2023
# 13202        Wyoming        Wyoming    3.8           57  Apr 26 - May 8, 2023
#
#       Time Period Start Date Time Period End Date  Value
# 0                 2020-04-23           2020-05-05   23.5
# 1                 2020-04-23           2020-05-05   32.7
# 2                 2020-04-23           2020-05-05   25.7
# 3                 2020-04-23           2020-05-05   24.8
# 4                 2020-04-23           2020-05-05   23.2
# ...                      ...                  ...    ...
# 13198             2023-04-26           2023-05-08   29.7
# 13199             2023-04-26           2023-05-08   31.2
# 13200             2023-04-26           2023-05-08   33.2
# 13201             2023-04-26           2023-05-08   27.5
# 13202             2023-04-26           2023-05-08   34.1
#
# [12582 rows x 10 columns]

# %%
#looking for dupes -- no dupes in df found 
mental_health_survey.loc[mental_health_survey.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Indicator, Group, State, Subgroup, Phase, Time Period, Time Period Label, Time Period Start Date, Time Period End Date, Value]
# Index: []

# %% [markdown]
# #survey_one.transpose()
# pd.melt(survey_one, id_vars=["Indicator", 'State', 'Time Period', 'Time Period Label', 'Time Period End Date', 'Value'], var_name=

# %%
Survey_data_by_age = mental_health_survey.loc[mental_health_survey['Group'] == 'By Age']

# %%
Survey_data_by_age
# Out:
#                                                Indicator   Group  \
# 1                        Symptoms of Depressive Disorder  By Age
# 2                        Symptoms of Depressive Disorder  By Age
# 3                        Symptoms of Depressive Disorder  By Age
# 4                        Symptoms of Depressive Disorder  By Age
# 5                        Symptoms of Depressive Disorder  By Age
# ...                                                  ...     ...
# 13128  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13129  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13130  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13131  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13132  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
#
#                State            Subgroup  Phase  Time Period  \
# 1      United States       18 - 29 years    1.0            1
# 2      United States       30 - 39 years    1.0            1
# 3      United States       40 - 49 years    1.0            1
# 4      United States       50 - 59 years    1.0            1
# 5      United States       60 - 69 years    1.0            1
# ...              ...                 ...    ...          ...
# 13128  United States       40 - 49 years    3.8           57
# 13129  United States       50 - 59 years    3.8           57
# 13130  United States       60 - 69 years    3.8           57
# 13131  United States       70 - 79 years    3.8           57
# 13132  United States  80 years and above    3.8           57
#
#           Time Period Label Time Period Start Date Time Period End Date  Value
# 1      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   32.7
# 2      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   25.7
# 3      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   24.8
# 4      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   23.2
# 5      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   18.4
# ...                     ...                    ...                  ...    ...
# 13128  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   34.8
# 13129  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   30.6
# 13130  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   24.2
# 13131  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   20.1
# 13132  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   18.1
#
# [1197 rows x 10 columns]

# %%
Survey_data_by_age
# Out:
#                                                Indicator   Group  \
# 1                        Symptoms of Depressive Disorder  By Age
# 2                        Symptoms of Depressive Disorder  By Age
# 3                        Symptoms of Depressive Disorder  By Age
# 4                        Symptoms of Depressive Disorder  By Age
# 5                        Symptoms of Depressive Disorder  By Age
# ...                                                  ...     ...
# 13128  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13129  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13130  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13131  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
# 13132  Symptoms of Anxiety Disorder or Depressive Dis...  By Age
#
#                State            Subgroup  Phase  Time Period  \
# 1      United States       18 - 29 years    1.0            1
# 2      United States       30 - 39 years    1.0            1
# 3      United States       40 - 49 years    1.0            1
# 4      United States       50 - 59 years    1.0            1
# 5      United States       60 - 69 years    1.0            1
# ...              ...                 ...    ...          ...
# 13128  United States       40 - 49 years    3.8           57
# 13129  United States       50 - 59 years    3.8           57
# 13130  United States       60 - 69 years    3.8           57
# 13131  United States       70 - 79 years    3.8           57
# 13132  United States  80 years and above    3.8           57
#
#           Time Period Label Time Period Start Date Time Period End Date  Value
# 1      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   32.7
# 2      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   25.7
# 3      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   24.8
# 4      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   23.2
# 5      Apr 23 - May 5, 2020             2020-04-23           2020-05-05   18.4
# ...                     ...                    ...                  ...    ...
# 13128  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   34.8
# 13129  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   30.6
# 13130  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   24.2
# 13131  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   20.1
# 13132  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   18.1
#
# [1197 rows x 10 columns]

# %%
Survey_data_by_sex = mental_health_survey.loc[mental_health_survey['Group'] == 'By Sex']

# %%
Survey_data_by_sex
# Out:
#                                                Indicator   Group  \
# 8                        Symptoms of Depressive Disorder  By Sex
# 9                        Symptoms of Depressive Disorder  By Sex
# 78                          Symptoms of Anxiety Disorder  By Sex
# 79                          Symptoms of Anxiety Disorder  By Sex
# 148    Symptoms of Anxiety Disorder or Depressive Dis...  By Sex
# ...                                                  ...     ...
# 12978                    Symptoms of Depressive Disorder  By Sex
# 13055                       Symptoms of Anxiety Disorder  By Sex
# 13056                       Symptoms of Anxiety Disorder  By Sex
# 13133  Symptoms of Anxiety Disorder or Depressive Dis...  By Sex
# 13134  Symptoms of Anxiety Disorder or Depressive Dis...  By Sex
#
#                State Subgroup  Phase  Time Period     Time Period Label  \
# 8      United States     Male    1.0            1  Apr 23 - May 5, 2020
# 9      United States   Female    1.0            1  Apr 23 - May 5, 2020
# 78     United States     Male    1.0            1  Apr 23 - May 5, 2020
# 79     United States   Female    1.0            1  Apr 23 - May 5, 2020
# 148    United States     Male    1.0            1  Apr 23 - May 5, 2020
# ...              ...      ...    ...          ...                   ...
# 12978  United States   Female    3.8           57  Apr 26 - May 8, 2023
# 13055  United States     Male    3.8           57  Apr 26 - May 8, 2023
# 13056  United States   Female    3.8           57  Apr 26 - May 8, 2023
# 13133  United States     Male    3.8           57  Apr 26 - May 8, 2023
# 13134  United States   Female    3.8           57  Apr 26 - May 8, 2023
#
#       Time Period Start Date Time Period End Date  Value
# 8                 2020-04-23           2020-05-05   20.8
# 9                 2020-04-23           2020-05-05   26.1
# 78                2020-04-23           2020-05-05   26.1
# 79                2020-04-23           2020-05-05   35.4
# 148               2020-04-23           2020-05-05   31.0
# ...                      ...                  ...    ...
# 12978             2023-04-26           2023-05-08   22.5
# 13055             2023-04-26           2023-05-08   24.5
# 13056             2023-04-26           2023-05-08   30.7
# 13133             2023-04-26           2023-05-08   29.5
# 13134             2023-04-26           2023-05-08   34.9
#
# [342 rows x 10 columns]

# %%
Survey_data_by_race = mental_health_survey.loc[mental_health_survey['Group'] == 'By Race/Hispanic ethnicity']

# %%
Survey_data_by_race
# Out:
#                                                Indicator  \
# 10                       Symptoms of Depressive Disorder
# 11                       Symptoms of Depressive Disorder
# 12                       Symptoms of Depressive Disorder
# 13                       Symptoms of Depressive Disorder
# 14                       Symptoms of Depressive Disorder
# ...                                                  ...
# 13141  Symptoms of Anxiety Disorder or Depressive Dis...
# 13142  Symptoms of Anxiety Disorder or Depressive Dis...
# 13143  Symptoms of Anxiety Disorder or Depressive Dis...
# 13144  Symptoms of Anxiety Disorder or Depressive Dis...
# 13145  Symptoms of Anxiety Disorder or Depressive Dis...
#
#                             Group          State  \
# 10     By Race/Hispanic ethnicity  United States
# 11     By Race/Hispanic ethnicity  United States
# 12     By Race/Hispanic ethnicity  United States
# 13     By Race/Hispanic ethnicity  United States
# 14     By Race/Hispanic ethnicity  United States
# ...                           ...            ...
# 13141  By Race/Hispanic ethnicity  United States
# 13142  By Race/Hispanic ethnicity  United States
# 13143  By Race/Hispanic ethnicity  United States
# 13144  By Race/Hispanic ethnicity  United States
# 13145  By Race/Hispanic ethnicity  United States
#
#                                            Subgroup  Phase  Time Period  \
# 10                               Hispanic or Latino    1.0            1
# 11                  Non-Hispanic White, single race    1.0            1
# 12                  Non-Hispanic Black, single race    1.0            1
# 13                  Non-Hispanic Asian, single race    1.0            1
# 14     Non-Hispanic, other races and multiple races    1.0            1
# ...                                             ...    ...          ...
# 13141                            Hispanic or Latino    3.8           57
# 13142               Non-Hispanic White, single race    3.8           57
# 13143               Non-Hispanic Black, single race    3.8           57
# 13144               Non-Hispanic Asian, single race    3.8           57
# 13145  Non-Hispanic, other races and multiple races    3.8           57
#
#           Time Period Label Time Period Start Date Time Period End Date  Value
# 10     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   29.4
# 11     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   21.4
# 12     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   25.6
# 13     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   23.6
# 14     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   28.3
# ...                     ...                    ...                  ...    ...
# 13141  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   36.6
# 13142  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   31.1
# 13143  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   34.2
# 13144  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   23.2
# 13145  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   39.2
#
# [855 rows x 10 columns]

# %%
Survey_data_by_edu= mental_health_survey.loc[mental_health_survey['Group'] == 'By Education']

# %%
Survey_data_by_edu
# Out:
#                                                Indicator         Group  \
# 15                       Symptoms of Depressive Disorder  By Education
# 16                       Symptoms of Depressive Disorder  By Education
# 17                       Symptoms of Depressive Disorder  By Education
# 18                       Symptoms of Depressive Disorder  By Education
# 85                          Symptoms of Anxiety Disorder  By Education
# ...                                                  ...           ...
# 13071                       Symptoms of Anxiety Disorder  By Education
# 13146  Symptoms of Anxiety Disorder or Depressive Dis...  By Education
# 13147  Symptoms of Anxiety Disorder or Depressive Dis...  By Education
# 13148  Symptoms of Anxiety Disorder or Depressive Dis...  By Education
# 13149  Symptoms of Anxiety Disorder or Depressive Dis...  By Education
#
#                State                         Subgroup  Phase  Time Period  \
# 15     United States  Less than a high school diploma    1.0            1
# 16     United States       High school diploma or GED    1.0            1
# 17     United States  Some college/Associate's degree    1.0            1
# 18     United States      Bachelor's degree or higher    1.0            1
# 85     United States  Less than a high school diploma    1.0            1
# ...              ...                              ...    ...          ...
# 13071  United States      Bachelor's degree or higher    3.8           57
# 13146  United States  Less than a high school diploma    3.8           57
# 13147  United States       High school diploma or GED    3.8           57
# 13148  United States  Some college/Associate's degree    3.8           57
# 13149  United States      Bachelor's degree or higher    3.8           57
#
#           Time Period Label Time Period Start Date Time Period End Date  Value
# 15     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   32.7
# 16     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   25.4
# 17     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   25.6
# 18     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   17.6
# 85     Apr 23 - May 5, 2020             2020-04-23           2020-05-05   37.3
# ...                     ...                    ...                  ...    ...
# 13071  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   21.0
# 13146  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   43.6
# 13147  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   35.0
# 13148  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   36.5
# 13149  Apr 26 - May 8, 2023             2023-04-26           2023-05-08   24.2
#
# [684 rows x 10 columns]

# %%
Survey_one_by_state= mental_health_survey.loc[mental_health_survey['Group'] == 'By State']

# %%
Survey_one_by_state
# Out:
#                                                Indicator     Group  \
# 19                       Symptoms of Depressive Disorder  By State
# 20                       Symptoms of Depressive Disorder  By State
# 21                       Symptoms of Depressive Disorder  By State
# 22                       Symptoms of Depressive Disorder  By State
# 23                       Symptoms of Depressive Disorder  By State
# ...                                                  ...       ...
# 13198  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 13199  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 13200  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 13201  Symptoms of Anxiety Disorder or Depressive Dis...  By State
# 13202  Symptoms of Anxiety Disorder or Depressive Dis...  By State
#
#                State       Subgroup  Phase  Time Period     Time Period Label  \
# 19           Alabama        Alabama    1.0            1  Apr 23 - May 5, 2020
# 20            Alaska         Alaska    1.0            1  Apr 23 - May 5, 2020
# 21           Arizona        Arizona    1.0            1  Apr 23 - May 5, 2020
# 22          Arkansas       Arkansas    1.0            1  Apr 23 - May 5, 2020
# 23        California     California    1.0            1  Apr 23 - May 5, 2020
# ...              ...            ...    ...          ...                   ...
# 13198       Virginia       Virginia    3.8           57  Apr 26 - May 8, 2023
# 13199     Washington     Washington    3.8           57  Apr 26 - May 8, 2023
# 13200  West Virginia  West Virginia    3.8           57  Apr 26 - May 8, 2023
# 13201      Wisconsin      Wisconsin    3.8           57  Apr 26 - May 8, 2023
# 13202        Wyoming        Wyoming    3.8           57  Apr 26 - May 8, 2023
#
#       Time Period Start Date Time Period End Date  Value
# 19                2020-04-23           2020-05-05   18.6
# 20                2020-04-23           2020-05-05   19.2
# 21                2020-04-23           2020-05-05   22.4
# 22                2020-04-23           2020-05-05   26.6
# 23                2020-04-23           2020-05-05   25.4
# ...                      ...                  ...    ...
# 13198             2023-04-26           2023-05-08   29.7
# 13199             2023-04-26           2023-05-08   31.2
# 13200             2023-04-26           2023-05-08   33.2
# 13201             2023-04-26           2023-05-08   27.5
# 13202             2023-04-26           2023-05-08   34.1
#
# [8721 rows x 10 columns]

# %%
 Survey_data_by_national_est = mental_health_survey.loc[mental_health_survey['Group'] == 'National Estimate']

# %%
 Survey_data_by_national_est
# Out:
#                                                Indicator              Group  \
# 0                        Symptoms of Depressive Disorder  National Estimate
# 70                          Symptoms of Anxiety Disorder  National Estimate
# 140    Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 210                      Symptoms of Depressive Disorder  National Estimate
# 280                         Symptoms of Anxiety Disorder  National Estimate
# ...                                                  ...                ...
# 12813                       Symptoms of Anxiety Disorder  National Estimate
# 12891  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
# 12969                    Symptoms of Depressive Disorder  National Estimate
# 13047                       Symptoms of Anxiety Disorder  National Estimate
# 13125  Symptoms of Anxiety Disorder or Depressive Dis...  National Estimate
#
#                State       Subgroup  Phase  Time Period  \
# 0      United States  United States    1.0            1
# 70     United States  United States    1.0            1
# 140    United States  United States    1.0            1
# 210    United States  United States    1.0            2
# 280    United States  United States    1.0            2
# ...              ...            ...    ...          ...
# 12813  United States  United States    3.8           56
# 12891  United States  United States    3.8           56
# 12969  United States  United States    3.8           57
# 13047  United States  United States    3.8           57
# 13125  United States  United States    3.8           57
#
#            Time Period Label Time Period Start Date Time Period End Date  \
# 0       Apr 23 - May 5, 2020             2020-04-23           2020-05-05
# 70      Apr 23 - May 5, 2020             2020-04-23           2020-05-05
# 140     Apr 23 - May 5, 2020             2020-04-23           2020-05-05
# 210     May 7 - May 12, 2020             2020-05-07           2020-05-12
# 280     May 7 - May 12, 2020             2020-05-07           2020-05-12
# ...                      ...                    ...                  ...
# 12813  Mar 29 - Apr 10, 2023             2023-03-29           2023-04-10
# 12891  Mar 29 - Apr 10, 2023             2023-03-29           2023-04-10
# 12969   Apr 26 - May 8, 2023             2023-04-26           2023-05-08
# 13047   Apr 26 - May 8, 2023             2023-04-26           2023-05-08
# 13125   Apr 26 - May 8, 2023             2023-04-26           2023-05-08
#
#        Value
# 0       23.5
# 70      30.8
# 140     35.9
# 210     24.1
# 280     30.0
# ...      ...
# 12813   28.1
# 12891   32.6
# 12969   21.8
# 13047   27.7
# 13125   32.3
#
# [171 rows x 10 columns]
