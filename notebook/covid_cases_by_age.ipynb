# %%
import pandas as pd
import numpy as np

# %%
covid_age_df = pd.read_csv('../data/COVID-19_Cases_and_Deaths_by_Age_Group.csv')

# %%
covid_age_df
# Out:
#      DateUpdated     AgeGroups  Total cases  Confirmed cases  Probable cases  \
# 0      5/27/2021           0-9        21266          19931.0          1335.0
# 1      5/27/2021        19-Oct        41363          37591.0          3772.0
# 2      5/27/2021         20-29        60808          54548.0          6260.0
# 3      5/27/2021         30-39        53926          48970.0          4956.0
# 4      5/27/2021         40-49        48453          44467.0          3986.0
# ...          ...           ...          ...              ...             ...
# 5332   5/26/2021         40-49        48434          44453.0          3981.0
# 5333   5/26/2021         50-59        51834          48000.0          3834.0
# 5334   5/26/2021         60-69        34348          32177.0          2171.0
# 5335   5/26/2021         70-79        17626          16584.0          1042.0
# 5336   5/26/2021  80 and older        16524          15074.0          1450.0
#
# ...

# %%
covid_age_df.dtypes
# Out:
# DateUpdated          object
# AgeGroups            object
# Total cases           int64
# Confirmed cases     float64
# Probable cases      float64
# Total case rate     float64
# Total deaths          int64
# Confirmed deaths    float64
# Probable deaths     float64
# dtype: object

# %%
age_cat_correction = { '19-Oct' : '18-29' }

# %%
covid_age_df['AgeGroups']  = covid_age_df['AgeGroups'].replace(age_cat_correction)

# %%
covid_age_df
# Out:
#      DateUpdated     AgeGroups  Total cases  Confirmed cases  Probable cases  \
# 0      5/27/2021           0-9        21266          19931.0          1335.0
# 1      5/27/2021         18-29        41363          37591.0          3772.0
# 2      5/27/2021         20-29        60808          54548.0          6260.0
# 3      5/27/2021         30-39        53926          48970.0          4956.0
# 4      5/27/2021         40-49        48453          44467.0          3986.0
# ...          ...           ...          ...              ...             ...
# 5332   5/26/2021         40-49        48434          44453.0          3981.0
# 5333   5/26/2021         50-59        51834          48000.0          3834.0
# 5334   5/26/2021         60-69        34348          32177.0          2171.0
# 5335   5/26/2021         70-79        17626          16584.0          1042.0
# 5336   5/26/2021  80 and older        16524          15074.0          1450.0
#
# ...
